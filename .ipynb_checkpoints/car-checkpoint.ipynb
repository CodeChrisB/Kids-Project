# %% [markdown]
# ## Project Cars
#
# ### Goals
# - Playing with real data ,make sense out it, find correlations between values.
# - Using specicif features of the libraries studied in class to strengthen the knowledge
#
# ### Dataset
# - https://www.kaggle.com/atechnohazard/battery-and-heating-data-in-real-driving-cycles?select=TripA01.csv
#
# ### Problems
# - The shear size of the data set. Creating a full pairplot of all 48 columns takes more than 15 minutes, even with optimized rendering
# - Understanding the Dataset the huge amount of data was enourmous to wrap our heads arround
#
# ### Result
# - Todo

# %%
#All libraries that are uses somewhere
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
import time
import math

# %%
trip = pd.read_csv('./TripB01.csv') # Get First Trip
trip = trip[trip['Time [s]'] % 1 == 0] # Get only every 10th row (1s,2s,3s,4s,5s....)
trip
# Out:
#        Time [s]  Velocity [km/h]  Elevation [m]  Throttle [%]  \
# 0           0.0          0.00000      449.00000           0.0
# 10          1.0          0.00000      449.00000           0.0
# 20          2.0          0.00000      449.00000           0.0
# 30          3.0          0.00000      449.00000           0.0
# 40          4.0          0.00000      449.00000           0.0
# ...         ...              ...            ...           ...
# 32470    3247.0          0.57881      476.00966           0.0
# 32480    3248.0          0.09375      476.00000           0.0
# 32490    3249.0          0.00000      476.00000           0.0
# 32500    3250.0          0.00000      476.00000           0.0
# 32510    3251.0          0.00000      476.00000           0.0
#
#        Motor Torque [Nm]  Longitudinal Acceleration [m/s^2]  \
# 0                0.00000                           -0.32930
# 10               0.00000                           -0.42098
# 20               0.00000                           -0.35800
# 30               0.00000                           -0.34662
# 40               0.00000                           -0.35230
# ...                  ...                                ...
# 32470            4.35177                            0.21247
# 32480            0.00000                           -0.28795
# 32490            0.00000                           -0.34132
# 32500            0.00000                           -0.36000
# 32510            0.00000                           -0.34236
#
#        Regenerative Braking Signal   Battery Voltage [V]  Battery Current [A]  \
# 0                               0.0            388.80000            -19.06128
# 10                              0.0            388.80000            -18.21941
# 20                              0.0            388.90000            -17.74028
# 30                              0.0            388.95974            -17.27922
# 40                              0.0            388.95976            -17.07927
# ...                             ...                  ...                  ...
# 32470                           0.0            373.54784             -3.63922
# 32480                           0.0            373.60000             -3.58716
# 32490                           0.0            373.60000             -3.86484
# 32500                           0.0            373.60000             -3.20841
# 32510                           0.0            373.60000             -3.23119
#
#        Battery Temperature [�C]  ...  Temperature Footweel Driver [�C]  \
# 0                           7.0  ...                           9.30159
# 10                          7.0  ...                           9.30159
# 20                          7.0  ...                           9.30159
# 30                          7.0  ...                           9.30159
# 40                          7.0  ...                           9.37547
# ...                         ...  ...                               ...
# 32470                      15.0  ...                          24.13947
# 32480                      15.0  ...                          24.13947
# 32490                      15.0  ...                          24.07120
# 32500                      15.0  ...                          24.05219
# 32510                      15.0  ...                          23.98393
#
#        Temperature Footweel Co-Driver [�C]  \
# 0                                  8.42878
# 10                                 8.49573
# 20                                 8.71690
# 30                                 8.91179
# 40                                 9.22024
# ...                                    ...
# 32470                             24.86533
# 32480                             24.83772
# 32490                             24.83772
# 32500                             24.83772
# 32510                             24.89738
#
#        Temperature Feetvent Co-Driver [�C]  Temperature Feetvent Driver [�C]  \
# 0                                  7.73053                           8.07965
# 10                                 7.99832                           8.37524
# 20                                 8.41439                           8.79826
# 30                                 8.91773                           9.53025
# 40                                 9.64223                          10.38966
# ...                                    ...                               ...
# 32470                             38.10452                          36.27161
# 32480                             38.10452                          36.27161
# 32490                             38.10452                          36.27161
# 32500                             38.10452                          36.27161
# 32510                             38.04486                          36.20333
#
#        Temperature Head Co-Driver [�C]  Temperature Head Driver [�C]  \
# 0                             12.53101                      13.49111
# 10                            12.53101                      13.49111
# 20                            12.53101                      13.34336
# 30                            12.53101                      13.31655
# 40                            12.45714                      13.31655
# ...                                ...                           ...
# 32470                         22.51915                      22.15101
# 32480                         22.48112                      22.13199
# 32490                         22.41285                      22.13199
# 32500                         22.39384                      22.13199
# 32510                         22.32558                      22.13199
#
#        Temperature Vent right [�C]   Temperature Vent central right [�C]  \
# 0                          10.26169                              9.65072
# 10                         10.26169                              9.65072
# 20                         10.26169                              9.71767
# 30                         10.26169                              9.67106
# 40                         10.26169                              9.65072
# ...                             ...                                  ...
# 32470                      29.78516                             27.63073
# 32480                      29.81277                             27.69040
# 32490                      29.81277                             27.71801
# 32500                      29.75311                             27.71801
# 32510                      29.72549                             27.71801
#
#        Temperature Vent central left [�C]  Temperature Vent right [�C]
# 0                                 9.65072                     10.34897
# 10                                9.65072                     10.34897
# 20                                9.65072                     10.34897
# 30                                9.58376                     10.27508
# 40                                9.56344                     10.26169
# ...                                   ...                          ...
# 32470                            29.11452                     28.22271
# 32480                            29.11452                     28.17342
# 32490                            29.05483                     28.22270
# 32500                            29.08692                     28.17342
# 32510                            29.11452                     28.22270
#
# [3252 rows x 48 columns]

# %%
def getTrip(n,m,x,y):
    return trip.iloc[n:m,x:y]

# %%
trip.isnull().sum()
# Out:
# Time [s]                             0
# Velocity [km/h]                      0
# Elevation [m]                        0
# Throttle [%]                         0
# Motor Torque [Nm]                    0
# Longitudinal Acceleration [m/s^2]    0
# Regenerative Braking Signal          0
# Battery Voltage [V]                  0
# dtype: int64

# %%
# Function to create an image
# @param1 string -> name of the image
# @param2 sns_plot -> the plot to render
# @return The renderd image


def makeImage(name,plot):
    start = time.time() 
    # render on pc  to make it faster
    path='./savedImages/'+name+".png"
    plot.savefig(path)
    plt.clf() # Clean parirplot figure from sns
    end = time.time()
    print("Render Time :"+str(math.ceil((end - start)*100)/100)+"s")
    print("FilePath: "+path)
    return Image(path) # Show pairplot as image

# %%
plot = sns.pairplot(getTrip(0,2000,4,6), height=2.0)
makeImage("Plot",plot) # Show pairplot as image
# Out:
# Render Time :0.33s
# FilePath: ./savedImages/Plot.png

# %%
fig, ax = plt.subplots(figsize=(40,40))         # Sample figsize in inches
sns.heatmap(trip.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>
